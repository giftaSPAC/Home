# %%
import random
from prettytable import PrettyTable

# Dummy inventory data with prices in INR and stock count
inventory = [
    {"item": "Silk Saree", "category": "Clothing", "gender": "F", "price": 5000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Gold Necklace", "category": "Jewelry", "gender": "F", "price": 15000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Copper Pooja Thali", "category": "Home Decor", "gender": "U", "price": 1000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Handwoven Shawl", "category": "Clothing", "gender": "F", "price": 3000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Silver Anklet", "category": "Jewelry", "gender": "F", "price": 8000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Brass Lamp", "category": "Home Decor", "gender": "U", "price": 2000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Cotton Kurti", "category": "Clothing", "gender": "F", "price": 2500, "stock_count": 15, "age_group": "Adult"},
    {"item": "Pearl Earrings", "category": "Jewelry", "gender": "F", "price": 12000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Wooden Wall Clock", "category": "Home Decor", "gender": "U", "price": 1500, "stock_count": 20, "age_group": "Adult"},
    {"item": "Leather Wallet", "category": "Accessories", "gender": "M", "price": 3000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Chanderi Saree", "category": "Clothing", "gender": "F", "price": 6000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Diamond Ring", "category": "Jewelry", "gender": "F", "price": 20000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Marble Ganesha Idol", "category": "Home Decor", "gender": "U", "price": 2500, "stock_count": 35, "age_group": "Adult"},
    {"item": "Linen Shirt", "category": "Clothing", "gender": "M", "price": 3500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Sapphire Necklace", "category": "Jewelry", "gender": "F", "price": 18000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Terracotta Showpiece", "category": "Home Decor", "gender": "U", "price": 1200, "stock_count": 15, "age_group": "Adult"},
    {"item": "Denim Jeans", "category": "Clothing", "gender": "M", "price": 2800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Ruby Bracelet", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Bamboo Wall Art", "category": "Home Decor", "gender": "U", "price": 1800, "stock_count": 30, "age_group": "Adult"},
    {"item": "Leather Backpack", "category": "Accessories", "gender": "U", "price": 4000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Kanjivaram Saree", "category": "Clothing", "gender": "F", "price": 8000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Platinum Ring", "category": "Jewelry", "gender": "F", "price": 25000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Antique Vase", "category": "Home Decor", "gender": "U", "price": 3000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Tuxedo Suit", "category": "Clothing", "gender": "M", "price": 7000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Emerald Necklace", "category": "Jewelry", "gender": "F", "price": 22000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Rustic Wall Shelf", "category": "Home Decor", "gender": "U", "price": 1800, "stock_count": 30, "age_group": "Adult"},
    {"item": "Canvas Backpack", "category": "Accessories", "gender": "U", "price": 3500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Banarasi Silk Saree", "category": "Clothing", "gender": "F", "price": 7000, "stock_count": 20, "age_group": "Adult"},
    {"item": "White Gold Bracelet", "category": "Jewelry", "gender": "F", "price": 18000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Modern Sculpture", "category": "Home Decor", "gender": "U", "price": 2000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Black T-shirt", "category": "Clothing", "gender": "M", "price": 1200, "stock_count": 35, "age_group": "Adult"},
    {"item": "Silver Bracelet", "category": "Jewelry", "gender": "F", "price": 8000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Glass Vase", "category": "Home Decor", "gender": "U", "price": 1500, "stock_count": 30, "age_group": "Adult"},
    {"item": "Casual Shoes", "category": "Footwear", "gender": "U", "price": 2500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Plaid Shirt", "category": "Clothing", "gender": "M", "price": 1800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Topaz Necklace", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Desk Organizer", "category": "Office", "gender": "U", "price": 2000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Printed Scarf", "category": "Clothing", "gender": "F", "price": 1000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Gold Watch", "category": "Accessories", "gender": "U", "price": 3500, "stock_count": 40, "age_group": "Adult"},
    {"item": "Kitchen Blender", "category": "Appliances", "gender": "U", "price": 5000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Striped Polo Shirt", "category": "Clothing", "gender": "M", "price": 1200, "stock_count": 20, "age_group": "Adult"},
    {"item": "Amethyst Ring", "category": "Jewelry", "gender": "F", "price": 20000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Bookshelf", "category": "Furniture", "gender": "U", "price": 7000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Backpack with USB Port", "category": "Accessories", "gender": "U", "price": 4000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Laptop Stand", "category": "Office", "gender": "U", "price": 1500, "stock_count": 20, "age_group": "Adult"},
    {"item": "Graphic T-shirt", "category": "Clothing", "gender": "M", "price": 800, "stock_count": 35, "age_group": "Adult"},
    {"item": "Opal Earrings", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Wall Mirror", "category": "Home Decor", "gender": "U", "price": 2500, "stock_count": 30, "age_group": "Adult"},
    {"item": "Running Shoes", "category": "Footwear", "gender": "U", "price": 3000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Summer Dress", "category": "Clothing", "gender": "F", "price": 1800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Bronze Necklace", "category": "Jewelry", "gender": "F", "price": 22000, "stock_count": 15, "age_group": "Adult"},

]

# Function to match keywords, gender, budget, and consider stock count
def match_keywords_to_inventory(preprocessed_data, inventory):
    # Dummy matching logic
    matched_items = [
        item
        for item in inventory
        if (
            any(keyword.lower() in item["category"].lower() for keyword in preprocessed_data["preferred_categories"])
            and ((item["gender"].lower() == preprocessed_data["gender"].lower()) or (item["gender"].lower() == "u"))
            and (item["price"] <= preprocessed_data["budget"])
            and (item["stock_count"] > 0)  # Consider items with positive stock count
        )
    ]
    return matched_items

# Example usage with budget and preferred categories input by numbers
user_name = input("Name: ")
occasion = "Birthday"
age = 30
gender = input("Gender (M/F): ")
print("Categories:")
print("1. Clothing")
print("2. Jewelry")
print("3. Home Decor")
selected_categories = input("Select preferred categories (comma-separated numbers): ").split(",")
preferred_categories = []

for category_num in selected_categories:
    if category_num == "1":
        preferred_categories.append("Clothing")
    elif category_num == "2":
        preferred_categories.append("Jewelry")
    elif category_num == "3":
        preferred_categories.append("Home Decor")

budget = int(input("Budget: "))

# Step 1: Preprocess user inputs
processed_data = {
    "user_name": user_name,
    "occasion": occasion,
    "age": age,
    "gender": gender,
    "preferred_categories": preferred_categories,
    "budget": budget,
}

# Step 2: Match keywords, gender, budget, and consider stock count
matched_items = match_keywords_to_inventory(processed_data, inventory)

# Shuffle the matched items randomly
random.shuffle(matched_items)

# Display randomized recommendations to the user within the budget
print("\n")
print("Thank you for choosing giftaSPAC")
print(f"Hello {user_name}, here are your personalized randomized recommendations within your budget:")
if matched_items:
    total_price = 0
    table = PrettyTable(["Item", "Price", "Category", "Gender", "Stock Count"])
    for item in matched_items:
        if total_price + item["price"] <= processed_data["budget"] and item["stock_count"] > 0:
            table.add_row([item["item"], item["price"], item["category"], item["gender"], item["stock_count"]])
            total_price += item["price"]
    if total_price == 0:
        print("Cannot predict within budget. Please adjust your preferences or budget.")
    else:
        print(table)
        print("Total price as per products:", total_price)
        print("Profit: ", budget - total_price)
else:
    print("Cannot predict within budget. Please adjust your preferences or budget.")
# Out:
# Name: Abhinav
# Gender (M/F): M
# Categories:
# 1. Clothing
# 2. Jewelry
# 3. Home Decor
# Select preferred categories (comma-separated numbers): 1,3
# Budget: 50000
#
#
# Thank you for choosing giftaSPAC
# Hello Abhinav, here are your personalized randomized recommendations within your budget:
# +----------------------+-------+------------+--------+-------------+
# |         Item         | Price |  Category  | Gender | Stock Count |
# +----------------------+-------+------------+--------+-------------+
# |   Graphic T-shirt    |  800  |  Clothing  |   M    |      35     |
# |    Black T-shirt     |  1200 |  Clothing  |   M    |      35     |
# | Terracotta Showpiece |  1200 | Home Decor |   U    |      15     |
# |  Wooden Wall Clock   |  1500 | Home Decor |   U    |      20     |
# |   Modern Sculpture   |  2000 | Home Decor |   U    |      25     |
# | Marble Ganesha Idol  |  2500 | Home Decor |   U    |      35     |
# ...

# %%
import random
from prettytable import PrettyTable
from fpdf import FPDF  # Import FPDF library for PDF generation

# Dummy inventory data with prices in INR and stock count
inventory = [
    {"item": "Silk Saree", "category": "Clothing", "gender": "F", "price": 5000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Gold Necklace", "category": "Jewelry", "gender": "F", "price": 15000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Copper Pooja Thali", "category": "Home Decor", "gender": "U", "price": 1000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Handwoven Shawl", "category": "Clothing", "gender": "F", "price": 3000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Silver Anklet", "category": "Jewelry", "gender": "F", "price": 8000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Brass Lamp", "category": "Home Decor", "gender": "U", "price": 2000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Cotton Kurti", "category": "Clothing", "gender": "F", "price": 2500, "stock_count": 15, "age_group": "Adult"},
    {"item": "Pearl Earrings", "category": "Jewelry", "gender": "F", "price": 12000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Wooden Wall Clock", "category": "Home Decor", "gender": "U", "price": 1500, "stock_count": 20, "age_group": "Adult"},
    {"item": "Leather Wallet", "category": "Accessories", "gender": "M", "price": 3000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Chanderi Saree", "category": "Clothing", "gender": "F", "price": 6000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Diamond Ring", "category": "Jewelry", "gender": "F", "price": 20000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Marble Ganesha Idol", "category": "Home Decor", "gender": "U", "price": 2500, "stock_count": 35, "age_group": "Adult"},
    {"item": "Linen Shirt", "category": "Clothing", "gender": "M", "price": 3500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Sapphire Necklace", "category": "Jewelry", "gender": "F", "price": 18000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Terracotta Showpiece", "category": "Home Decor", "gender": "U", "price": 1200, "stock_count": 15, "age_group": "Adult"},
    {"item": "Denim Jeans", "category": "Clothing", "gender": "M", "price": 2800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Ruby Bracelet", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Bamboo Wall Art", "category": "Home Decor", "gender": "U", "price": 1800, "stock_count": 30, "age_group": "Adult"},
    {"item": "Leather Backpack", "category": "Accessories", "gender": "U", "price": 4000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Kanjivaram Saree", "category": "Clothing", "gender": "F", "price": 8000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Platinum Ring", "category": "Jewelry", "gender": "F", "price": 25000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Antique Vase", "category": "Home Decor", "gender": "U", "price": 3000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Tuxedo Suit", "category": "Clothing", "gender": "M", "price": 7000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Emerald Necklace", "category": "Jewelry", "gender": "F", "price": 22000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Rustic Wall Shelf", "category": "Home Decor", "gender": "U", "price": 1800, "stock_count": 30, "age_group": "Adult"},
    {"item": "Canvas Backpack", "category": "Accessories", "gender": "U", "price": 3500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Banarasi Silk Saree", "category": "Clothing", "gender": "F", "price": 7000, "stock_count": 20, "age_group": "Adult"},
    {"item": "White Gold Bracelet", "category": "Jewelry", "gender": "F", "price": 18000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Modern Sculpture", "category": "Home Decor", "gender": "U", "price": 2000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Black T-shirt", "category": "Clothing", "gender": "M", "price": 1200, "stock_count": 35, "age_group": "Adult"},
    {"item": "Silver Bracelet", "category": "Jewelry", "gender": "F", "price": 8000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Glass Vase", "category": "Home Decor", "gender": "U", "price": 1500, "stock_count": 30, "age_group": "Adult"},
    {"item": "Casual Shoes", "category": "Footwear", "gender": "U", "price": 2500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Plaid Shirt", "category": "Clothing", "gender": "M", "price": 1800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Topaz Necklace", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Desk Organizer", "category": "Office", "gender": "U", "price": 2000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Printed Scarf", "category": "Clothing", "gender": "F", "price": 1000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Gold Watch", "category": "Accessories", "gender": "U", "price": 3500, "stock_count": 40, "age_group": "Adult"},
    {"item": "Kitchen Blender", "category": "Appliances", "gender": "U", "price": 5000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Striped Polo Shirt", "category": "Clothing", "gender": "M", "price": 1200, "stock_count": 20, "age_group": "Adult"},
    {"item": "Amethyst Ring", "category": "Jewelry", "gender": "F", "price": 20000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Bookshelf", "category": "Furniture", "gender": "U", "price": 7000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Backpack with USB Port", "category": "Accessories", "gender": "U", "price": 4000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Laptop Stand", "category": "Office", "gender": "U", "price": 1500, "stock_count": 20, "age_group": "Adult"},
    {"item": "Graphic T-shirt", "category": "Clothing", "gender": "M", "price": 800, "stock_count": 35, "age_group": "Adult"},
    {"item": "Opal Earrings", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Wall Mirror", "category": "Home Decor", "gender": "U", "price": 2500, "stock_count": 30, "age_group": "Adult"},
    {"item": "Running Shoes", "category": "Footwear", "gender": "U", "price": 3000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Summer Dress", "category": "Clothing", "gender": "F", "price": 1800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Bronze Necklace", "category": "Jewelry", "gender": "F", "price": 22000, "stock_count": 15, "age_group": "Adult"},

]

# Function to match keywords, gender, budget, and consider stock count
def match_keywords_to_inventory(preprocessed_data, inventory):
    # Dummy matching logic
    matched_items = [
        item
        for item in inventory
        if (
            any(keyword.lower() in item["category"].lower() for keyword in preprocessed_data["preferred_categories"])
            and ((item["gender"].lower() == preprocessed_data["gender"].lower()) or (item["gender"].lower() == "u"))
            and (item["price"] <= preprocessed_data["budget"])
            and (item["stock_count"] > 0)  # Consider items with positive stock count
        )
    ]
    return matched_items

# Example usage with budget and preferred categories input by numbers
user_name = input("Name: ")
occasion = "Birthday"
age = 30
gender = input("Gender (M/F): ")
address = input("Enter your address: ")
print("Categories:")
print("1. Clothing")
print("2. Jewelry")
print("3. Home Decor")
selected_categories = input("Select preferred categories (comma-separated numbers): ").split(",")
preferred_categories = []

for category_num in selected_categories:
    if category_num == "1":
        preferred_categories.append("Clothing")
    elif category_num == "2":
        preferred_categories.append("Jewelry")
    elif category_num == "3":
        preferred_categories.append("Home Decor")

budget = int(input("Budget: "))

# Step 1: Preprocess user inputs
processed_data = {
    "user_name": user_name,
    "occasion": occasion,
    "age": age,
    "gender": gender,
    "preferred_categories": preferred_categories,
    "budget": budget,
}

# Step 2: Match keywords, gender, budget, and consider stock count
matched_items = match_keywords_to_inventory(processed_data, inventory)
random.shuffle(matched_items)

# Display randomized recommendations to the user within the budget
print("\n")
print("Thank you for choosing giftaSPAC")
print(f"Hello {user_name}, here are your personalized randomized recommendations within your budget:")

if matched_items:
    total_price = 0
    table = PrettyTable(["Item", "Price", "Category", "Gender", "Stock Count"])
    for item in matched_items:
        if total_price + item["price"] <= processed_data["budget"] and item["stock_count"] > 0:
            table.add_row([item["item"], item["price"], item["category"], item["gender"], item["stock_count"]])
            total_price += item["price"]

    if total_price == 0:
        print("Cannot predict within budget. Please adjust your preferences or budget.")
    else:
        print(table)
        print("Total price as per products:", total_price)
        print("Profit: ", budget - total_price)

        # Step 3: Ask the user to approve the order
        user_approval = input("Do you approve the order? (Y/N): ").upper()

        if user_approval == "Y":
            # Step 4: Generate a bill as a PDF
            pdf = FPDF()
            pdf.add_page()
            pdf.set_font("Arial", size=12)
            pdf.cell(200, 10, txt="GiftaSPAC - Order Confirmation", ln=True, align="C")
            pdf.ln(10)
            pdf.cell(200, 5, txt=f"Name: {user_name}", ln=True)
            pdf.cell(200, 5, txt=f"Address: {address}", ln=True)
            pdf.cell(200, 5, txt=f"Occasion: Happy {occasion}", ln=True)
            pdf.ln(7)

            # Adding the table to the PDF
            pdf.cell(200, 5, txt="Here you go, SPAC's Recommended Products:", ln=True)
            pdf.ln(5)

            # Set column widths for the table
            col_widths = [50, 25, 30, 25, 25]

            # Add table headers
            for i in range(len(table.field_names)):
                pdf.cell(col_widths[i], 10, txt=str(table.field_names[i]), border=1, align="C")
            pdf.ln()

            # Add table rows
            for row in table._rows:
                for i in range(len(row)):
                    pdf.cell(col_widths[i], 10, txt=str(row[i]), border=1)
                pdf.ln()

            pdf.ln(10)
            pdf.cell(200, 5, txt=f"Total Price: {total_price}", ln=True)
            pdf.ln(7)
            pdf.cell(200, 5, txt="Thank you for choosing giftaSPAC!", ln=True)

            pdf.output("order_confirmation.pdf")

            print("Order confirmed! Order details have been saved in order_confirmation.pdf.")
        else:
            print("Order canceled.")

else:
    print("Cannot predict within budget. Please adjust your preferences or budget.")
# Out:
# Name: Abhinav chebrolu
# Gender (M/F): M
# Enter your address: Adk
# Categories:
# 1. Clothing
# 2. Jewelry
# 3. Home Decor
# Select preferred categories (comma-separated numbers): 1,3
# Budget: 40000
#
#
# Thank you for choosing giftaSPAC
# Hello Abhinav chebrolu, here are your personalized randomized recommendations within your budget:
# +----------------------+-------+------------+--------+-------------+
# |         Item         | Price |  Category  | Gender | Stock Count |
# +----------------------+-------+------------+--------+-------------+
# |     Tuxedo Suit      |  7000 |  Clothing  |   M    |      15     |
# |     Plaid Shirt      |  1800 |  Clothing  |   M    |      20     |
# |   Graphic T-shirt    |  800  |  Clothing  |   M    |      35     |
# |  Striped Polo Shirt  |  1200 |  Clothing  |   M    |      20     |
# |     Wall Mirror      |  2500 | Home Decor |   U    |      30     |
# |    Black T-shirt     |  1200 |  Clothing  |   M    |      35     |
# ...

# %%
import random
from prettytable import PrettyTable
from fpdf import FPDF
from termcolor import colored

# Dummy inventory data with prices in INR and stock count
inventory = [
    {"item": "Silk Saree", "category": "Clothing", "gender": "F", "price": 5000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Gold Necklace", "category": "Jewelry", "gender": "F", "price": 15000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Copper Pooja Thali", "category": "Home Decor", "gender": "U", "price": 1000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Handwoven Shawl", "category": "Clothing", "gender": "F", "price": 3000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Silver Anklet", "category": "Jewelry", "gender": "F", "price": 8000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Brass Lamp", "category": "Home Decor", "gender": "U", "price": 2000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Cotton Kurti", "category": "Clothing", "gender": "F", "price": 2500, "stock_count": 15, "age_group": "Adult"},
    {"item": "Pearl Earrings", "category": "Jewelry", "gender": "F", "price": 12000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Wooden Wall Clock", "category": "Home Decor", "gender": "U", "price": 1500, "stock_count": 20, "age_group": "Adult"},
    {"item": "Leather Wallet", "category": "Accessories", "gender": "M", "price": 3000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Chanderi Saree", "category": "Clothing", "gender": "F", "price": 6000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Diamond Ring", "category": "Jewelry", "gender": "F", "price": 20000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Marble Ganesha Idol", "category": "Home Decor", "gender": "U", "price": 2500, "stock_count": 35, "age_group": "Adult"},
    {"item": "Linen Shirt", "category": "Clothing", "gender": "M", "price": 3500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Sapphire Necklace", "category": "Jewelry", "gender": "F", "price": 18000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Terracotta Showpiece", "category": "Home Decor", "gender": "U", "price": 1200, "stock_count": 15, "age_group": "Adult"},
    {"item": "Denim Jeans", "category": "Clothing", "gender": "M", "price": 2800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Ruby Bracelet", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Bamboo Wall Art", "category": "Home Decor", "gender": "U", "price": 1800, "stock_count": 30, "age_group": "Adult"},
    {"item": "Leather Backpack", "category": "Accessories", "gender": "U", "price": 4000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Kanjivaram Saree", "category": "Clothing", "gender": "F", "price": 8000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Platinum Ring", "category": "Jewelry", "gender": "F", "price": 25000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Antique Vase", "category": "Home Decor", "gender": "U", "price": 3000, "stock_count": 20, "age_group": "Adult"},
    {"item": "Tuxedo Suit", "category": "Clothing", "gender": "M", "price": 7000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Emerald Necklace", "category": "Jewelry", "gender": "F", "price": 22000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Rustic Wall Shelf", "category": "Home Decor", "gender": "U", "price": 1800, "stock_count": 30, "age_group": "Adult"},
    {"item": "Canvas Backpack", "category": "Accessories", "gender": "U", "price": 3500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Banarasi Silk Saree", "category": "Clothing", "gender": "F", "price": 7000, "stock_count": 20, "age_group": "Adult"},
    {"item": "White Gold Bracelet", "category": "Jewelry", "gender": "F", "price": 18000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Modern Sculpture", "category": "Home Decor", "gender": "U", "price": 2000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Black T-shirt", "category": "Clothing", "gender": "M", "price": 1200, "stock_count": 35, "age_group": "Adult"},
    {"item": "Silver Bracelet", "category": "Jewelry", "gender": "F", "price": 8000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Glass Vase", "category": "Home Decor", "gender": "U", "price": 1500, "stock_count": 30, "age_group": "Adult"},
    {"item": "Casual Shoes", "category": "Footwear", "gender": "U", "price": 2500, "stock_count": 25, "age_group": "Adult"},
    {"item": "Plaid Shirt", "category": "Clothing", "gender": "M", "price": 1800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Topaz Necklace", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Desk Organizer", "category": "Office", "gender": "U", "price": 2000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Printed Scarf", "category": "Clothing", "gender": "F", "price": 1000, "stock_count": 35, "age_group": "Adult"},
    {"item": "Gold Watch", "category": "Accessories", "gender": "U", "price": 3500, "stock_count": 40, "age_group": "Adult"},
    {"item": "Kitchen Blender", "category": "Appliances", "gender": "U", "price": 5000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Striped Polo Shirt", "category": "Clothing", "gender": "M", "price": 1200, "stock_count": 20, "age_group": "Adult"},
    {"item": "Amethyst Ring", "category": "Jewelry", "gender": "F", "price": 20000, "stock_count": 15, "age_group": "Adult"},
    {"item": "Bookshelf", "category": "Furniture", "gender": "U", "price": 7000, "stock_count": 30, "age_group": "Adult"},
    {"item": "Backpack with USB Port", "category": "Accessories", "gender": "U", "price": 4000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Laptop Stand", "category": "Office", "gender": "U", "price": 1500, "stock_count": 20, "age_group": "Adult"},
    {"item": "Graphic T-shirt", "category": "Clothing", "gender": "M", "price": 800, "stock_count": 35, "age_group": "Adult"},
    {"item": "Opal Earrings", "category": "Jewelry", "gender": "F", "price": 16000, "stock_count": 40, "age_group": "Adult"},
    {"item": "Wall Mirror", "category": "Home Decor", "gender": "U", "price": 2500, "stock_count": 30, "age_group": "Adult"},
    {"item": "Running Shoes", "category": "Footwear", "gender": "U", "price": 3000, "stock_count": 25, "age_group": "Adult"},
    {"item": "Summer Dress", "category": "Clothing", "gender": "F", "price": 1800, "stock_count": 20, "age_group": "Adult"},
    {"item": "Bronze Necklace", "category": "Jewelry", "gender": "F", "price": 22000, "stock_count": 15, "age_group": "Adult"},

]

# Function to match keywords, gender, budget, and consider stock count
def match_keywords_to_inventory(preprocessed_data, inventory):
    # Dummy matching logic
    matched_items = [
        item
        for item in inventory
        if (
            any(keyword.lower() in item["category"].lower() for keyword in preprocessed_data["preferred_categories"])
            and ((item["gender"].lower() == preprocessed_data["gender"].lower()) or (item["gender"].lower() == "u"))
            and (item["price"] <= preprocessed_data["budget"])
            and (item["stock_count"] > 0)  # Consider items with positive stock count
        )
    ]
    return matched_items

# Example usage with budget and preferred categories input by numbers
user_name = input("Name: ")
occasion = "Birthday"
age = 30
gender = input("Gender (M/F): ")
address = input("Enter your address: ")
print("Categories:")
print("1. Clothing")
print("2. Jewelry")
print("3. Home Decor")
selected_categories = input("Select preferred categories (comma-separated numbers): ").split(",")
preferred_categories = []

for category_num in selected_categories:
    if category_num == "1":
        preferred_categories.append("Clothing")
    elif category_num == "2":
        preferred_categories.append("Jewelry")
    elif category_num == "3":
        preferred_categories.append("Home Decor")

budget = int(input("Budget: "))

# Step 1: Preprocess user inputs
processed_data = {
    "user_name": user_name,
    "occasion": occasion,
    "age": age,
    "gender": gender,
    "preferred_categories": preferred_categories,
    "budget": budget,
}

# Step 2: Match keywords, gender, budget, and consider stock count
matched_items = match_keywords_to_inventory(processed_data, inventory)
random.shuffle(matched_items)

# Display randomized recommendations to the user within the budget
print("\n")
print("Thank you for choosing giftaSPAC")
print(f"Hello {user_name}, here are your personalized randomized recommendations within your budget:")

if matched_items:
    total_price = 0
    table = PrettyTable(["Item", "Price", "Category", "Gender", "Stock Count"])
    for item in matched_items:
        if total_price + item["price"] <= processed_data["budget"] and item["stock_count"] > 0:
            table.add_row([item["item"], item["price"], item["category"], item["gender"], item["stock_count"]])
            total_price += item["price"]

    if total_price == 0:
        print("Cannot predict within budget. Please adjust your preferences or budget.")
    else:
        print(table)
        print("Total price as per products:", total_price)
        print("Profit: ", budget - total_price)

        # Step 3: Ask the user to approve the order
        user_approval = input("Do you approve the order? (Y/N): ").upper()

        if user_approval == "Y":
            # Step 4: Generate a bill as a PDF
            pdf = FPDF()
            pdf.add_page()
            pdf.set_font("Arial", size=12)
            pdf.image("https://abhinavchebrolu.co.in/SPAC/images/Logo%20red.png", x=10, y=8, w=33)

            pdf.set_font("Times", size=14)

            pdf.cell(200, 10, txt="Tax Invoice/Bill of Supply - Order Confirmation \t\t\t", ln=True, align="R")
            pdf.ln(15)

            pdf.set_font("Arial", "B",size=12)

            pdf.cell(200, 5, txt=f"CustName: {user_name}", ln=True)
            pdf.cell(200, 5, txt=f"CustAddress: {address}", ln=True)
            pdf.cell(200, 5, txt=f"Occasion: Happy {occasion}", ln=True)
            pdf.ln(7)

            pdf.set_font("Arial", size=12)

            # Adding the table to the PDF
            pdf.cell(200, 5, txt="Here you go, SPAC's Recommended Products:", ln=True)
            pdf.ln(5)

            # Set column widths for the table
            col_widths = [50, 25, 30, 25, 25]

            # Add table headers
            for i in range(len(table.field_names)):
                pdf.cell(col_widths[i], 10, txt=str(table.field_names[i]), border=1, align="C")
            pdf.ln()

            # Add table rows
            for row in table._rows:
                for i in range(len(row)):
                    pdf.cell(col_widths[i], 10, txt=str(row[i]), border=1)
                pdf.ln()

            pdf.ln(10)
            pdf.cell(200, 5, txt=f"Total Price: {total_price}", ln=True)
            pdf.ln(7)
            pdf.cell(200, 5, txt="Thank you for choosing giftaSPAC!", ln=True)

            pdf.output("order_confirmation.pdf")

            print("Order confirmed! Order details have been saved in order_confirmation.pdf.")
        else:
            print("Order canceled.")

else:
    print("Cannot predict within budget. Please adjust your preferences or budget.")
# Out:
# Name: Pandu Chebrolu
# Gender (M/F): M
# Enter your address: Addanki
# Categories:
# 1. Clothing
# 2. Jewelry
# 3. Home Decor
# Select preferred categories (comma-separated numbers): 1,3
# Budget: 70000
#
#
# Thank you for choosing giftaSPAC
# Hello Pandu Chebrolu, here are your personalized randomized recommendations within your budget:
# +----------------------+-------+------------+--------+-------------+
# |         Item         | Price |  Category  | Gender | Stock Count |
# +----------------------+-------+------------+--------+-------------+
# |   Graphic T-shirt    |  800  |  Clothing  |   M    |      35     |
# |   Modern Sculpture   |  2000 | Home Decor |   U    |      25     |
# |    Black T-shirt     |  1200 |  Clothing  |   M    |      35     |
# |     Wall Mirror      |  2500 | Home Decor |   U    |      30     |
# |     Plaid Shirt      |  1800 |  Clothing  |   M    |      20     |
# | Terracotta Showpiece |  1200 | Home Decor |   U    |      15     |
# ...
